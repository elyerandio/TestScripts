# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

apo71 = pd.read_excel('D://2013//apo//Sched7.1.xls', 'Sched7.1')
apo72 = pd.read_excel('D://2013//apo//Sched7.2.xls', 'Sched7.2')
apo73 = pd.read_excel('D://2013//apo//Sched7.3.xls', 'Sched7.3')
apo74 = pd.read_excel('D://2013//apo//Sched7.4.xls', 'Sched7.4')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
print apo71, '\n'
print apo72, '\n'
print apo73, '\n'
print apo74, '\n'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 12
# Data columns (total 33 columns):
# SCHEDULE_NUM                 12  non-null values
# FTYPE_CODE                   12  non-null values
# TIN_EMPYR                    12  non-null values
# BRANCH_CODE_EMPLYR           12  non-null values
# RETRN_PERIOD                 11  non-null values
# SEQ_NUM                      10  non-null values
# TIN                          10  non-null values
# BRANCH_CODE                  10  non-null values
# LAST_NAME                    10  non-null values
# FIRST_NAME                   10  non-null values
# MIDDLE_NAME                  10  non-null values
# EMPLOYMENT_FROM              10  non-null values
# EMPLOYMENT_TO                10  non-null values
# GROSS_COMP_INCOME            11  non-null values
# PRES_NONTAX_13TH_MONTH       11  non-null values
# PRES_NONTAX_DE_MINIMIS       11  non-null values
# PRES_NONTAX_SSS_ETC          11  non-null values
# ...

# %%
apo71 = apo71.drop(0)

# %%
print apo71
print apo71.TAX_DUE, apo71.PRES_TAX_WTHLD, apo71.AMT_WTHLD_DEC, apo71.OVER_WTHLD
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 1 to 12
# Data columns (total 33 columns):
# SCHEDULE_NUM                 11  non-null values
# FTYPE_CODE                   11  non-null values
# TIN_EMPYR                    11  non-null values
# BRANCH_CODE_EMPLYR           11  non-null values
# RETRN_PERIOD                 11  non-null values
# SEQ_NUM                      10  non-null values
# TIN                          10  non-null values
# BRANCH_CODE                  10  non-null values
# LAST_NAME                    10  non-null values
# FIRST_NAME                   10  non-null values
# MIDDLE_NAME                  10  non-null values
# EMPLOYMENT_FROM              10  non-null values
# EMPLOYMENT_TO                10  non-null values
# GROSS_COMP_INCOME            11  non-null values
# PRES_NONTAX_13TH_MONTH       11  non-null values
# PRES_NONTAX_DE_MINIMIS       11  non-null values
# PRES_NONTAX_SSS_ETC          11  non-null values
# ...

# %%
for idx, val in apo71.iterrows():
    amt = abs(val['TAX_DUE'] - (val['PRES_TAX_WTHLD'] + val['AMT_WTHLD_DEC']))
    print "%s, %s => %.2f - (%.2f + %.2f) = %.2f" % (val['LAST_NAME'], val['FIRST_NAME'], val['TAX_DUE'], val['PRES_TAX_WTHLD'], 
                                                     val['AMT_WTHLD_DEC'], amt)
    
    if abs(val['TAX_DUE'] - (val['PRES_TAX_WTHLD'] + val['AMT_WTHLD_DEC'])) <> val['OVER_WTHLD']:
        print '\t',val['LAST_NAME'], val['FIRST_NAME'], amt, val['OVER_WTHLD']
# Out:
# SAREN, JONATHAN => 82830.40 - (104227.39 + 0.00) = 21396.99
# 	SAREN JONATHAN 21396.99 21396.99
# OBERIANO, GREGORIO REICH => 519712.01 - (237987.83 + 281724.18) = 0.00
# RUBIO, ROY => 81841.13 - (81841.13 + 0.00) = 0.00
# GALLEGO, LESTER => 13021.09 - (13021.09 + 0.00) = 0.00
# FUENTES, RENATO => 2075.56 - (2075.56 + 0.00) = 0.00
# MACAIRAN, MARLON => 632.98 - (559.45 + 0.00) = 73.53
# 	MACAIRAN MARLON 73.53 73.53
# FRANCISCO, EDWARD => 0.00 - (13868.60 + 0.00) = 13868.60
# LIBREA, JAYSON => 1622.21 - (6556.18 + 0.00) = 4933.97
# BACACAO, SERGS => 0.00 - (10232.16 + 0.00) = 10232.16
# KUAN WONG, RUSSELL => 42602.97 - (42602.97 + 0.00) = 0.00
# nan, nan => nan - (nan + nan) = nan
# 	nan nan nan nan
# nan, nan => 744338.35 - (512972.36 + 281724.18) = 50358.19
# 	nan nan 50358.19 50505.25

# %%
apo_over = apo71[abs(apo71.TAX_DUE - (apo71.PRES_TAX_WTHLD+apo71.AMT_WTHLD_DEC)) <> apo71.OVER_WTHLD]
print apo_over.index
# Out:
# Int64Index([1, 6, 11, 12], dtype=int64)
