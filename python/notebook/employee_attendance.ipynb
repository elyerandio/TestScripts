# %%
import pyodbc
conn = pyodbc.connect('DSN=QSI-Ely7-SQL; UID=sa; PWD=justdoit')
cur = conn.cursor()
cur.execute("Select * from employee_schedule where schedule_date > '2013-01-01' order by schedule_date")
for rec in cur:
    print rec.EMPLOYEE_NO, rec.SCHEDULE_DATE, rec.SCHEDULE_TYPE, rec.CREATED_DATE
# Out:
# 0207 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0249 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0311 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0353 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0440 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0469 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0493 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0496 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0529 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0555 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0558 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0562 2013-01-02 00:00:00 2207 2013-02-22 18:17:52.793000
# 0006 2013-01-02 00:00:00 2005 2013-02-22 18:18:28.053000
# 0037 2013-01-02 00:00:00 2005 2013-02-22 18:18:28.053000
# 0106 2013-01-02 00:00:00 2005 2013-02-22 18:18:28.053000
# 0161 2013-01-02 00:00:00 2005 2013-02-22 18:18:28.053000
# ...
