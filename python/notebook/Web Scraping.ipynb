# %%
import urllib2

site = urllib2.urlopen("http://www.yahoo.com")
html = site.read()
print html
# Out:
# ['<!DOCTYPE html>\n', '<html lang="en-PH" class="y-fp-bg y-fp-pg-grad  bkt711" style="">\n', '<!-- m2 template  -->\n', '<head>\n', '    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n', '\n', '    <title>Yahoo Philippines</title>\n', '    <meta http-equiv="X-UA-Compatible" content="chrome=1">\n', '    <meta name="description" content="Welcome to Yahoo, the world\'s most visited homepage. Quickly find what you\'re searching for, get in touch with friends and stay informed with the latest news and information.">\n', '    <meta name="keywords" content="yahoo, yahoo home page, yahoo homepage, yahoo search, yahoo mail, yahoo messenger, yahoo games, news, finance, sport, entertainment">\n', '    \n', '    \n', '    <script type="text/javascript">\n', '        //Roundtrip\n', '        rtTop = Number(new Date());\n', '\n', "        document.documentElement.className += ' jsenabled';\n", '    </script>\n', '\n', '    \n', '    <script type="text/javascript">\n', '    (f
# ...

# %%
import os
print os.getcwd()
# Out:
# C:\Users\ely\Documents\IPython Notebooks
